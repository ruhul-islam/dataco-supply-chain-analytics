# %%
# Imports and connection helper

from dotenv import load_dotenv
import os
import snowflake.connector
import pandas as pd

load_dotenv()

def get_connection():
    return snowflake.connector.connect(
        user=os.getenv('SNOWFLAKE_USER'),
        password=os.getenv('SNOWFLAKE_PASSWORD'),
        account=os.getenv('SNOWFLAKE_ACCOUNT'),
        authenticator='username_password_mfa',
        database='DATACO_DB',
        schema='SUPPLY_CHAIN',
        warehouse='DATACO_WH'
    )

print("✅ Helper function ready")
# Out:
# ✅ Helper function ready

# %%
# Setup Snowflake environment

conn = get_connection()
cursor = conn.cursor()

setup_commands = [
    "USE DATABASE DATACO_DB",
    "USE SCHEMA SUPPLY_CHAIN",
    "USE WAREHOUSE DATACO_WH"
]

for command in setup_commands:
    cursor.execute(command)
    print(f"✅ {command}")

print("\n✅ Snowflake environment ready!")
# Out:
# ✅ USE DATABASE DATACO_DB
# ✅ USE SCHEMA SUPPLY_CHAIN
# ✅ USE WAREHOUSE DATACO_WH
#
# ✅ Snowflake environment ready!

# %%
# Create tables

tables = {

    "dim_customer": """
        CREATE TABLE IF NOT EXISTS dim_customer (
            customer_id         INTEGER PRIMARY KEY,
            first_name          VARCHAR,
            last_name           VARCHAR,
            customer_email      VARCHAR,
            customer_segment    VARCHAR,
            customer_city       VARCHAR,
            customer_state      VARCHAR,
            customer_country    VARCHAR,
            customer_street     VARCHAR,
            customer_zipcode    VARCHAR
        )
    """,

    "dim_category": """
        CREATE TABLE IF NOT EXISTS dim_category (
            category_id         INTEGER PRIMARY KEY,
            category_name       VARCHAR NOT NULL
        )
    """,

    "dim_department": """
        CREATE TABLE IF NOT EXISTS dim_department (
            department_id       INTEGER PRIMARY KEY,
            department_name     VARCHAR NOT NULL
        )
    """,

    "dim_product": """
        CREATE TABLE IF NOT EXISTS dim_product (
            product_card_id     INTEGER PRIMARY KEY,
            product_name        VARCHAR,
            product_image       VARCHAR,
            product_price       FLOAT,
            product_status      INTEGER,
            category_id         INTEGER
        )
    """,

    "dim_location": """
        CREATE TABLE IF NOT EXISTS dim_location (
            location_id         INTEGER AUTOINCREMENT PRIMARY KEY,
            market              VARCHAR,
            order_region        VARCHAR,
            order_country       VARCHAR,
            order_state         VARCHAR,
            order_city          VARCHAR,
            latitude            FLOAT,
            longitude           FLOAT
        )
    """,

    "fact_orders": """
        CREATE TABLE IF NOT EXISTS fact_orders (
            order_item_id               INTEGER PRIMARY KEY,
            order_id                    INTEGER,
            order_customer_id           INTEGER,
            customer_id                 INTEGER,
            product_card_id             INTEGER,
            department_id               INTEGER,
            location_id                 INTEGER,
            shipping_mode               VARCHAR,
            date_id                     INTEGER,
            order_date                  DATE,
            shipping_date               DATE,
            real_shipping_days          INTEGER,
            scheduled_shipment_days     INTEGER,
            delay_days                  INTEGER,
            late_delivery_risk          INTEGER,
            is_late                     INTEGER,
            delivery_status             VARCHAR,
            order_status                VARCHAR,
            transaction_type            VARCHAR,
            order_item_quantity         INTEGER,
            order_item_discount         FLOAT,
            order_item_discount_rate    FLOAT,
            order_item_product_price    FLOAT,
            order_item_profit_ratio     FLOAT,
            sales                       FLOAT,
            order_item_total            FLOAT,
            order_profit_per_order      FLOAT,
            benefit_per_order           FLOAT,
            sales_per_customer          FLOAT
        )
    """
}

for table_name, ddl in tables.items():
    cursor.execute(ddl)
    print(f"✅ Created: {table_name}")

print("\n✅ All tables created!")
# Out:
# ✅ Created: dim_customer
# ✅ Created: dim_category
# ✅ Created: dim_department
# ✅ Created: dim_product
# ✅ Created: dim_location
# ✅ Created: fact_orders
#
# ✅ All tables created!

# %%
data_df = pd.read_pickle('./data/dataco_cleaned.pkl')

data_df.shape
# Out:
# (180519, 49)

# %%
data_df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %% [markdown]
# ## Creating Tables

# %%
# dim_customer

dim_customer_cols = {
    'Customer Id':      'customer_id',
    'Customer Fname':   'first_name',
    'Customer Lname':   'last_name',
    'Customer Segment': 'customer_segment',
    'Customer City':    'customer_city',
    'Customer State':   'customer_state',
    'Customer Country': 'customer_country',
    'Customer Street':  'customer_street',
    'Customer Zipcode': 'customer_zipcode'
}

dim_customer = (
    data_df[list(dim_customer_cols.keys())]
    .drop_duplicates(subset=['Customer Id'])
    .rename(columns=dim_customer_cols)
    .reset_index(drop=True)
)

dim_customer
# Out:
#        customer_id first_name  last_name customer_segment customer_city  \
# 0            20755      Cally   Holloway         Consumer        Caguas
# 1            19492      Irene       Luna         Consumer        Caguas
# 2            19491    Gillian  Maldonado         Consumer      San Jose
# 3            19490       Tana       Tate      Home Office   Los Angeles
# 4            19489       Orli  Hendricks        Corporate        Caguas
# ...            ...        ...        ...              ...           ...
# 20647        18586      Diana       Tran      Home Office        Caguas
# 20648        16322      Anika  Davenport      Home Office        Caguas
# 20649        18579       Yuri      Smith      Home Office        Caguas
# 20650        16244   Hyacinth       Witt      Home Office        Caguas
# 20651         2677       Mary      Davis      Home Office        Caguas
#
#       customer_state customer_country           customer_street  \
# ...

# %%
# dim_category

dim_category_cols = {
    'Category Id':   'category_id',
    'Category Name': 'category_name'
}

dim_category = (
    data_df[list(dim_category_cols.keys())]
    .drop_duplicates(subset=['Category Id'])
    .rename(columns=dim_category_cols)
    .reset_index(drop=True)
)

dim_category
# Out:
#     category_id         category_name
# 0            73        Sporting Goods
# 1            17                Cleats
# 2            29         Shop By Sport
# 3            24       Women's Apparel
# 4            13           Electronics
# 5            12          Boxing & MMA
# 6             9      Cardio Equipment
# 7            41              Trade-In
# 8            37           Electronics
# 9            38      Kids' Golf Clubs
# 10           44    Hunting & Shooting
# 11            3   Baseball & Softball
# 12           18        Men's Footwear
# 13           43      Camping & Hiking
# 14           65  Consumer Electronics
# 15           62              Cameras
# 16           64             Computers
# 17            4            Basketball
# 18            2                Soccer
# 19           26        Girls' Apparel
# 20           40           Accessories
# 21           76      Women's Clothing
# 22           66                Crafts
# 23           70        Men's Clothing
# ...

# %%
# dim_department

dim_department_cols = {
    'Department Id':   'department_id',
    'Department Name': 'department_name'
}

dim_department = (
    data_df[list(dim_department_cols.keys())]
    .drop_duplicates(subset=['Department Id'])
    .rename(columns=dim_department_cols)
    .reset_index(drop=True)
)

dim_department
# Out:
#     department_id     department_name
# 0               2             Fitness
# 1               4             Apparel
# 2               5                Golf
# 3               3            Footwear
# 4               6            Outdoors
# 5               7            Fan Shop
# 6              10          Technology
# 7               8           Book Shop
# 8               9          Discs Shop
# 9              11            Pet Shop
# 10             12  Health and Beauty

# %%
# dim_product

dim_product_cols = {
    'Product Card Id': 'product_card_id',
    'Product Name':    'product_name',
    'Product Image':   'product_image',
    'Product Price':   'product_price',
    'Product Status':  'product_status',
    'Category Id':     'category_id'
}

dim_product = (
    data_df[list(dim_product_cols.keys())]
    .drop_duplicates(subset=['Product Card Id'])
    .rename(columns=dim_product_cols)
    .reset_index(drop=True)
)

dim_product
# Out:
#      product_card_id                                   product_name  \
# 0               1360                                   Smart watch
# 1                365               Perfect Fitness Perfect Rip Deck
# 2                627  Under Armour Girls' Toddler Spine Surge Runni
# 3                502           Nike Men's Dri-FIT Victory Golf Polo
# 4                278     Under Armour Men's Compression EV SL Slide
# ..               ...                                            ...
# 113              646     Merrell Women's Grassbow Sport Hiking Shoe
# 114             1361                                          Toys
# 115             1073                    Pelican Sunstream 100 Kayak
# 116             1059                    Pelican Maverick 100X Kayak
# 117             1014               O'Brien Men's Neoprene Life Vest
#
#                                          product_image  product_price  \
# 0         http://images.acmesports.sports/Smart+watch      327.750000
# ...

# %%
# dim_location

dim_location_cols = {
    'Market':        'market',
    'Order Region':  'order_region',
    'Order Country': 'order_country',
    'Order State':   'order_state',
    'Order City':    'order_city',
    'Latitude':      'latitude',
    'Longitude':     'longitude'
}

dim_location = (
    data_df[list(dim_location_cols.keys())]
    .drop_duplicates()
    .rename(columns=dim_location_cols)
    .reset_index(drop=True)
)

dim_location
# Out:
#              market    order_region order_country         order_state  \
# 0      Pacific Asia  Southeast Asia     Indonesia     Java Occidental
# 1      Pacific Asia      South Asia         India            Rajastán
# 2      Pacific Asia      South Asia         India            Rajastán
# 3      Pacific Asia         Oceania     Australia          Queensland
# 4      Pacific Asia         Oceania     Australia          Queensland
# ...             ...             ...           ...                 ...
# 64862  Pacific Asia  Southeast Asia       Vietnam  Ciudad Ho Chi Minh
# 64863  Pacific Asia    Eastern Asia         China               Hubei
# 64864  Pacific Asia  Southeast Asia       Malasia               Sabah
# 64865  Pacific Asia  Southeast Asia     Indonesia        Java Central
# 64866  Pacific Asia      South Asia         India      Madhya Pradesh
#
#              order_city   latitude   longitude
# 0                Bekasi  18.251453  -66.037056
# ...

# %%
fact_orders_cols = {
    'Order Item Id':                 'order_item_id',
    'Order Id':                      'order_id',
    'Order Customer Id':             'order_customer_id',
    'Customer Id':                   'customer_id',
    'Product Card Id':               'product_card_id',
    'Department Id':                 'department_id',
    'Market':                        'market',
    'Order Region':                  'order_region',
    'Order Country':                 'order_country',
    'Order State':                   'order_state',
    'Order City':                    'order_city',
    'Shipping Mode':                 'shipping_mode',
    'order date (DateOrders)':       'order_date',
    'shipping date (DateOrders)':    'shipping_date',
    'Days for shipping (real)':      'real_shipping_days',
    'Days for shipment (scheduled)': 'scheduled_shipment_days',
    'delay_days':                    'delay_days',
    'Late_delivery_risk':            'late_delivery_risk',
    'is_late':                       'is_late',
    'Delivery Status':               'delivery_status',
    'Order Status':                  'order_status',
    'Type':                          'transaction_type',
    'Order Item Quantity':           'order_item_quantity',
    'Order Item Discount':           'order_item_discount',
    'Order Item Discount Rate':      'order_item_discount_rate',
    'Order Item Product Price':      'order_item_product_price',
    'Order Item Profit Ratio':       'order_item_profit_ratio',
    'Sales':                         'sales',
    'Order Item Total':              'order_item_total',
    'Order Profit Per Order':        'order_profit_per_order',
    'Benefit per order':             'benefit_per_order',
    'Sales per customer':            'sales_per_customer'
}

fact_orders = (
    data_df[list(fact_orders_cols.keys())]
    .rename(columns=fact_orders_cols)
    .reset_index(drop=True)
)

fact_orders['order_date'] = pd.to_datetime(fact_orders['order_date']).dt.date
fact_orders['shipping_date'] = pd.to_datetime(fact_orders['shipping_date']).dt.date

fact_orders
# Out:
#         order_item_id  order_id  order_customer_id  customer_id  \
# 0              180517     77202              20755        20755
# 1              179254     75939              19492        19492
# 2              179253     75938              19491        19491
# 3              179252     75937              19490        19490
# 4              179251     75936              19489        19489
# ...               ...       ...                ...          ...
# 180514          65177     26043               1005         1005
# 180515          65161     26037               9141         9141
# 180516          65129     26024                291          291
# 180517          65126     26022               2813         2813
# 180518          65113     26018               7547         7547
#
#         product_card_id  department_id        market    order_region  \
# 0                  1360              2  Pacific Asia  Southeast Asia
# ...

# %%
from snowflake.connector.pandas_tools import write_pandas

conn = get_connection()

tables_to_load = {
    'DIM_CUSTOMER':   dim_customer,
    'DIM_CATEGORY':   dim_category,
    'DIM_DEPARTMENT': dim_department,
    'DIM_PRODUCT':    dim_product,
    'DIM_LOCATION':   dim_location,
    'FACT_ORDERS':    fact_orders
}

for table_name, df in tables_to_load.items():
    
    # Uppercase column names to match Snowflake
    df_upload = df.copy()
    df_upload.columns = df_upload.columns.str.upper()
    
    success, chunks, rows, output = write_pandas(
        conn=conn,
        df=df_upload,
        table_name=table_name,
        database='DATACO_DB',
        schema='SUPPLY_CHAIN',
        auto_create_table=True,
        overwrite=True,
        quote_identifiers=False
    )
    print(f"✅ {table_name}: {rows:,} rows — success: {success}")

conn.close()
print("\n✅ All tables loaded!")
# Out:
# ✅ DIM_CUSTOMER: 20,652 rows — success: True
# ✅ DIM_CATEGORY: 51 rows — success: True
# ✅ DIM_DEPARTMENT: 11 rows — success: True
# ✅ DIM_PRODUCT: 118 rows — success: True
# ✅ DIM_LOCATION: 64,867 rows — success: True
# ✅ FACT_ORDERS: 180,519 rows — success: True
#
# ✅ All tables loaded!
